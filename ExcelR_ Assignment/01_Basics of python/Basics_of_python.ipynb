# %% [markdown]
# # PYTHON PROGRAMMING ASSIGNMENT :

# %% [markdown]
# **Exercise 1: Prime Numbers**
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
# Take input from users
num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print("Not a Prime Number")
            break
    else:
        print("Prime Number")
else:
    print("Not a Prime Number")
# Out:
# Enter a number:  6
# Not a Prime Number

# %% [markdown]
# **Exercise 2: Product of Random Numbers**
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
#Import required libraries
import numpy as np 

#Generate random Number 
num1 = np.random.randint(1,100)
num2 = np.random.randint(1,100)

# Ask the user for the product
answer = int(input(f"What is {num1} × {num2}? "))

# Product of the num1 and num2 
product = num1 * num2

# Condition
if answer == product :
    print("Good, You are Genius")
else:
    print("Doob Ke Mar Ja")
    print(f"The correct answer is {num1 * num2}.")
# Out:
# What is 78 × 52?  7
# Doob Ke Mar Ja
# The correct answer is 4056.

# %% [markdown]
# **Exercise 3: Squares of Even/Odd Numbers**
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
# To get output in array 
even_square = []
odd_square = []

# using for loop :
for i in range(100,201):
    if i % 2 == 0:
        sqr = i*i
        even_square.append(sqr)        
    else:
        od_sqr = i*i
        odd_square.append(od_sqr)

#Print Output
print("The Even squares are:\n",even_square)
print("The Odd squares are :\n",odd_square)
# Out:
# The Even squares are:
#  [10000, 10404, 10816, 11236, 11664, 12100, 12544, 12996, 13456, 13924, 14400, 14884, 15376, 15876, 16384, 16900, 17424, 17956, 18496, 19044, 19600, 20164, 20736, 21316, 21904, 22500, 23104, 23716, 24336, 24964, 25600, 26244, 26896, 27556, 28224, 28900, 29584, 30276, 30976, 31684, 32400, 33124, 33856, 34596, 35344, 36100, 36864, 37636, 38416, 39204, 40000]
# The Odd squares are :
#  [10201, 10609, 11025, 11449, 11881, 12321, 12769, 13225, 13689, 14161, 14641, 15129, 15625, 16129, 16641, 17161, 17689, 18225, 18769, 19321, 19881, 20449, 21025, 21609, 22201, 22801, 23409, 24025, 24649, 25281, 25921, 26569, 27225, 27889, 28561, 29241, 29929, 30625, 31329, 32041, 32761, 33489, 34225, 34969, 35721, 36481, 37249, 38025, 38809, 39601]

# %% [markdown]
# #### **Exercise 4. Problem Statement (Question): Hospital Billing System**
# A hospital charges its patients based on the following:
# •	Room charges per day: ₹2,000
# •	Doctor consultation fee (flat): ₹1,500
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# •	Medicine charges: Total cost of medicines provided
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# •	Stayed for 4 days
# •	Had 3 lab tests
# •	Had medicine charges of ₹2,400

# %%
room_charge = 2000
doctor_charge = 1500
lab_test_charge = 300


stayed = int (input ("How much days patient stayed in hospital:"))
lab_test = int (input("How much lab test:"))
medicine_charge = int (input("Enter the medicine charge:"))

print(f"Stayed Charge : {stayed} * {2000}  = {stayed * 2000}")
print(f"Lab Charge : {lab_test} * {300} =    {lab_test * 300}")
print(f"Medicine Charge : {medicine_charge}")


total_bill =  (stayed * 2000) + (lab_test * 300) + (medicine_charge) 
print(f"Total Bill : {total_bill}")
# Out:
# How much days patient stayed in hospital: 3
# How much lab test: 3
# Enter the medicine charge: 3
# Stayed Charge : 3 * 2000  = 6000
# Lab Charge : 3 * 300 =    900
# Medicine Charge : 3
# Total Bill : 6903
