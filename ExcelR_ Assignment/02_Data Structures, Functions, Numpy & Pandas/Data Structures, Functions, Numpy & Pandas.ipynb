# %% [markdown]
# # Python Assignment: Data Structures, Functions, Numpy & Pandas
# Instructions
# • Attempt all questions.
# • Submit the completed assignment in .ipynb format.
# • Use appropriate function definitions and comments for clarity.

# %% [markdown]
# ## Assignment Questions:

# %% [markdown]
# #### **Section A: Data Structures & Control Structures**
# 1.	Create a list of 5 integers. Perform and print the result of the following operations: append, extend, insert, remove, pop, clear, index, count, sort, and reverse.

# %%
list1 = [1,40,30,40,59]

list1.append(6)
list1.insert(6,7)
list1.remove(7)
list1.pop(5)

print(list1.count(40))
list1.sort()
list.reverse(list1)

# list.clear(list1)
print(list1)
# Out:
# 2
# [59, 40, 40, 30, 1]

# %% [markdown]
# **2.	Create a tuple that stores 3 student names. Try changing the second name in the tuple. What happens? Explain why.**
# A tuple is immutable, which means its elements cannot be changed, added, or removed after the tuple is created.

# %%
# Create a tuple
students = ("Alice", "Bob", "Charlie")

print("Original Tuple:", students)

# Try changing the second name
# students[1] = "David"
# Out:
# Original Tuple: ('Alice', 'Bob', 'Charlie')

# %% [markdown]
# **3.	Create a set of integers with some duplicate values. Print the set and explain the output.**
# Explanation
# A set in Python stores only unique elements. If duplicate values are provided, Python automatically removes them. Also, sets are unordered, so the order of elements in the output is not guaranteed.
# In the example:
# 10 appears twice.
# 20 appears twice.
# 30 appears twice.

# %%
# Create a set with duplicate values
numbers = {10, 20, 30, 40, 20, 30, 50, 10}

print("Set:", numbers)
# Out:
# Set: {50, 20, 40, 10, 30}

# %% [markdown]
# **4.	Create a dictionary with the keys: 'name', 'age', and 'city'. Update the age and add a new key 'email'. Print the final dictionary.**

# %%
# Create a dictionary
student = {
    "name": "Alice",
    "age": 20,
    "city": "New York"
}

# Update the age
student["age"] = 21

# Add a new key
student["email"] = "alice@example.com"

# Print the final dictionary
print(student)
# Out:
# {'name': 'Alice', 'age': 21, 'city': 'New York', 'email': 'alice@example.com'}

# %% [markdown]
# **5.	 Write a script that checks if a person is eligible to vote (age ≥ 18). Take age as a variable and print the appropriate message.**

# %%
age = int(input("Enter the age :"))
if age >= 18: 
    print("Eligible for Voting")
else:
    print("Not eligible for voting")
# Out:
# Enter the age : 34
# Eligible for Voting

# %% [markdown]
# **6.	Given a 'marks' variable, print the grade:**
# - 90 and above: 'A'
# - 75–89: 'B'
# - 50–74: 'C'
# - Below 50: 'Fail'

# %%
marks = int(input("Enter your marks "))
if marks >= 90:
    print("A")
elif marks >= 75 and  marks <= 89 : 
    print("B")
elif marks >= 50 and marks <= 74:
    print("C")
else:
    print("Fail")
# Out:
# Enter your marks  74
# C

# %% [markdown]
# **7.	Given a number, check if it's positive, and if it is also even. If not positive, print if it's zero or negative.**

# %%
# Given number
num = 8

# Check the number
if num > 0:
    print("The number is positive.")

    if num % 2 == 0:
        print("The number is also even.")
    else:
        print("The number is odd.")

elif num == 0:
    print("The number is zero.")

else:
    print("The number is negative.")
# Out:
# The number is positive.
# The number is also even.

# %% [markdown]
# ### Section B: Numpy
# **8.	Create:**
# - A scalar using np.array(5)
# - A 1D array with values 1 to 5
# - A 2D array (2x3) with values from 10 to 60 in steps of 10

# %%
import numpy as np

# 1. Scalar (0D array)
scalar = np.array(5)

# 2. 1D array with values 1 to 5
array_1d = np.array([1, 2, 3, 4, 5])

# 3. 2D array (2x3) with values from 10 to 60
array_2d = np.array([
    [10, 20, 30],
    [40, 50, 60]
])

# Print the arrays
print("Scalar:")
print(scalar)

print("\n1D Array:")
print(array_1d)

print("\n2D Array:")
print(array_2d)
# Out:
# Scalar:
# 5
#
# 1D Array:
# [1 2 3 4 5]
#
# 2D Array:
# [[10 20 30]
#  [40 50 60]]

# %% [markdown]
# **9.	Generate a 4x4 Numpy array of random integers between 0 and 100 using np.random.randint().**

# %%
import numpy as np

# Generate a 4x4 array of random integers between 0 and 100
random_array = np.random.randint(0, 101, size=(4, 4))

print("4x4 Random Integer Array:")
print(random_array)
# Out:
# 4x4 Random Integer Array:
# [[21 85 52 58]
#  [57  2 94 35]
#  [ 0 67 44 96]
#  [27 75  2 88]]

# %% [markdown]
# **10.	Create a 2D numpy array of shape (3x3). Convert it into a pandas DataFrame and add column names: 'A', 'B', 'C'.**

# %%
import numpy as np
import pandas as pd

# Create a 3x3 NumPy array
array = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

# Convert the NumPy array into a Pandas DataFrame
df = pd.DataFrame(array, columns=["A", "B", "C"])

# Print the DataFrame
print(df)
# Out:
#     A   B   C
# 0  10  20  30
# 1  40  50  60
# 2  70  80  90

# %% [markdown]
# ### Section C: Exploring Pandas
# 11.	Create a small DataFrame manually with 10 rows and columns: 'Name', 'Age', 'City', and 'Salary'. Then:
# - Use .info(), .describe()
# - Select 'Name' and 'City' columns
# - Drop 'City' column
# - Fill any missing values in 'Salary' column with the mean
# - Remove any duplicate rows

# %%
import pandas as pd 
import numpy as np 
df = pd.DataFrame({
    "Name" : ["Shahid Afridi", "Shahjad Alam", "Shaik Afrin","Ananya", "Shaik Afrin", "Md.Sohail","Saddam", "Shammi", "Arshad",  "Md.Imran"],
    "Age" : [21, 22, 23, 18, 23, 14, 24, 27, 20,  16],
    "City" : ['Mumbai', 'Patna', 'Andhra Pradesh', 'Motihari','Andhra Pradesh','Chennai','Mumbai',np.nan, 'Andhra Pradesh', 'Ranchi'],
        "Salary" : [40000,50000,700000,345566,700000,356446,35644,890750,6784847, np.nan ]
})

# %%
df
# Out:
#             Name  Age            City     Salary
# 0  Shahid Afridi   21          Mumbai    40000.0
# 1   Shahjad Alam   22           Patna    50000.0
# 2    Shaik Afrin   23  Andhra Pradesh   700000.0
# 3         Ananya   18        Motihari   345566.0
# 4    Shaik Afrin   23  Andhra Pradesh   700000.0
# 5      Md.Sohail   14         Chennai   356446.0
# 6         Saddam   24          Mumbai    35644.0
# 7         Shammi   27             NaN   890750.0
# 8         Arshad   20  Andhra Pradesh  6784847.0
# 9       Md.Imran   16          Ranchi        NaN

# %%
# Info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    9 non-null      object
#  3   Salary  9 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
# Describe 
df.describe()
# Out:
#              Age        Salary
# count  10.000000  9.000000e+00
# mean   20.800000  1.100361e+06
# std     3.910101  2.155292e+06
# min    14.000000  3.564400e+04
# 25%    18.500000  5.000000e+04
# 50%    21.500000  3.564460e+05
# 75%    23.000000  7.000000e+05
# max    27.000000  6.784847e+06

# %%
# Drop City Columns:
df.drop (columns = 'City', inplace = True)

# %%
# Fill Salary with mean
mean_salary = df["Salary"].mean()
df["Salary"] = df["Salary"].fillna(mean_salary)

# %%
# Check duplicate rows
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Drop duplicates
df.drop_duplicates(inplace = True)

# %%
# Verify 
df.duplicated().sum()
# Out:
# np.int64(0)
